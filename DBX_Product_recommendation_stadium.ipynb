# %% [markdown]
# -sandbox
# # ライブイベント向け商品レコメンド - スタジアムアナリティクス
# <img style='float: right' width='600px' src='https://github.com/QuentinAmbard/databricks-demo/raw/main/media/resources/images/product_reco_stadium-notif.png'>
#
# **ユースケースの概要**
# * スポーツのライブ中継では大量の顧客データが生成されます。より良いファン体験を実現するのに活用できます。ファンとの関わりは、売上や顧客維持率の向上に直結します。このノートブックでは、ファンの購買履歴とスタジアムの座席の位置情報をもとにパーソナライズされた割引オファーを作成し、イベント中の追加販売を促進し、より個人的な体験を実現する方法を紹介します。
# *目標：ファンへキャンペーンのオファーのプッシュ通知を送信します。
#
# **ソリューションのビジネスインパクト**
# * **ファン・エンゲージメントと顧客維持：** イベントに参加している間、より良い経験をしているファンは、将来的に別のイベントのために戻ってくる可能性が高くなります。
# * **収益の増加：**ファンに パーソナライズされた割引キャンペーンを送信すると、イベント中にスタジアムの中の店からの購入が増えるのでお店(ベンダー)の収益の増加にも繋がります。
#
# <!-- Collect usage data (view). Remove it to disable collection. View README for more details.  -->
# <img width="1px" src="https://www.google-analytics.com/collect?v=1&gtm=GTM-NKQ8TT7&tid=UA-163989034-1&cid=555&aip=1&t=event&ec=field_demos&ea=display&dp=%2F42_field_demos%2Fmedia%2Fproduct_recommender_stadium%2Fnotebook&dt=MEDIA_USE_CASE">
# <!-- [metadata={"description":"Product recommendation for live events. This demo shows how to create a personalized discount for a fan based on their purchasing history and location of where they sit in a stadium to drive additional sales during the game and create a more individualized experience.",
#  "authors":["dan.morris@databricks.com"],
#   "db_resources":{},
#   "search_tags":{"vertical": "media", "step": "Data Engineering", "components": ["sparkml", "mlflow", "als", "recommender"]},
#                  "canonicalUrl": {"AWS": "", "Azure": "", "GCP": ""}}] -->

# %% [markdown]
# # 設定と準備

# %% [markdown]
# ## ダミデータ作成のdbldatagenのインストール

# %%
# %pip install git+https://github.com/databrickslabs/dbldatagen faker
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Collecting git+https://github.com/databrickslabs/dbldatagen
#   Cloning https://github.com/databrickslabs/dbldatagen to /tmp/pip-req-build-vd4k56q9
#   Running command git clone -q https://github.com/databrickslabs/dbldatagen /tmp/pip-req-build-vd4k56q9
# Collecting faker
#   Using cached Faker-15.3.2-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: python-dateutil&gt;=2.4 in /databricks/python3/lib/python3.8/site-packages (from faker) (2.8.1)
# Requirement already satisfied: six&gt;=1.5 in /databricks/python3/lib/python3.8/site-packages (from python-dateutil&gt;=2.4-&gt;faker) (1.15.0)
# Building wheels for collected packages: dbldatagen
#   Building wheel for dbldatagen (setup.py): started
#   Building wheel for dbldatagen (setup.py): finished with status &#39;done&#39;
#   Created wheel for dbldatagen: filename=dbldatagen-0.2.1-py3-none-any.whl size=68625 sha256=5f54234cac074e51fb5e2ee18b2c5e24dcfb8707ee7193d4df3d94b2d067cfbf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dcpw6i13/wheels/1b/cf/fb/80521865607b111812b23df1e198828a4294d0cf05b970ad70
# Successfully built dbldatagen
# Installing collected packages: faker, dbldatagen
# Successfully installed dbldatagen-0.2.1 faker-15.3.2
# Python interpreter will be restarted.
# </div>

# %% [markdown]
# ## データの準備
#
# 以下リンクからデータのZipファイルをダウンロードして/FileStore/tmpの直下に手動でアップロードしてください。
#
# https://github.com/yulan-yan/Product_recommendation_stadium/blob/main/stadium_recommender.zip

# %%
# 一回のみ実行
# !unzip /dbfs/FileStore/tmp/stadium_recommender.zip -d /dbfs/FileStore/tmp/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## パスなど変数の設定

# %%
pandas_data_path = "/dbfs/FileStore/tmp/stadium_recommender"
data_path = "/FileStore/tmp/stadium_recommender"
dbName = "yulanDB"
current_user = "Yulan"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Databaseの準備

# %%
spark.sql("drop database if exists yulanDB CASCADE")
spark.sql("create database if not exists yulanDB")
spark.sql("use yulanDB")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: DataFrame[]</div>

# %% [markdown]
# # レコメンデーションシステムの構築のワークフロー

# %% [markdown]
# ## Step 1： データを読込・加工したらraw tablesに書き込む
#
# <img src="https://github.com/QuentinAmbard/databricks-demo/raw/main/media/resources/images/product_reco_stadium-1.png" width="1000px">

# %% [markdown]
# ### VendorとItemのリスト（stadium_vendors）
#
# <img src="https://github.com/QuentinAmbard/databricks-demo/raw/main/media/resources/images/product_reco_stadium-vendors.png" width="400px" style="float: right" />
#
# ベンダーリストとアイテムのリストを[https://www.fordfield.com/restaurant-partners](Ford Field)へCSVファイルとしてアップロードしています。
#
# PandasとSparkを使えば、これらのデータを簡単に取り込み、データ型を調整することができます。

# %%
print("Vendors Item type data generation...")
import pandas as pd
from pyspark.sql.functions import col

pandasDF = pd.read_csv(f"{pandas_data_path}/data/vendors.csv")
df_items = spark.createDataFrame(pandasDF, ['vendor_id', 'vendor_location_number', 'vendor_name', 'vendor_scope', 'section', 'item_id', 'item_type', 'item', 'price', 'error'])
for c in "vendor_id", "vendor_location_number", "section", "item_id", "price":
  df_items = df_items.withColumn(c, col(c).cast('int'))

spark.sql("drop table if exists stadium_vendors")
df_items.write.saveAsTable("stadium_vendors")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Vendors Item type data generation...
# </div>

# %% [markdown]
# ### チケットの売上データ（Tickets sales）
#
# <img src="https://github.com/QuentinAmbard/databricks-demo/raw/main/media/resources/images/product_reco_stadium-pricing.png" width="400px" style="float: right" />
#
# チケットの売上データもraw tableに書き込みます。

# %%
print("Ticket sales data generation...")
import dbldatagen as dg
from pyspark.sql.types import *
from pyspark.sql import functions as F
from faker import Faker
fake = Faker()

fake_name = F.udf(fake.name)
fake_phone = F.udf(fake.phone_number)

data_rows = 70000
df_spec = (dg.DataGenerator(spark, name="ticket_sales", rows=data_rows, partitions=4)
                            .withIdOutput()
                            .withColumn("game_id", IntegerType(), values=['3'])
                            .withColumn("ticket_price", IntegerType(), expr="floor(rand() * 350)")
                            .withColumn("gate_entrance", StringType(), values=['a', 'b', 'c', 'd', 'e', ], random=True, weights=[9, 1, 1, 2, 2])
                            .withColumn("section_number", IntegerType(), minValue=100, maxValue=347, random=True)
                            .withColumn("row_number", IntegerType(), minValue=1, maxValue=35 , random=True)
                            .withColumn("seat_number", IntegerType(), minValue=1, maxValue=30, random=True)
                            .withColumn("ticket_type", StringType(), values=['single_game', 'packaged_game', 'season_holder'], random=True, weights=[7, 2, 1]))
df_tickets = df_spec.build().withColumnRenamed("id", "customer_id")
df_tickets = df_tickets.withColumn("customer_name", fake_name())
df_tickets = df_tickets.withColumn("phone_number", fake_phone())

spark.sql("drop table if exists ticket_sales")
df_tickets.write.saveAsTable("ticket_sales")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Ticket sales data generation...
# INFO: Version : VersionInfo(major=&#39;0&#39;, minor=&#39;2&#39;, patch=&#39;1&#39;, release=&#39;&#39;, build=&#39;&#39;)
# </div>

# %% [markdown]
# ### イベントのスケジュール（Games）
#
# 試合のイベントデータも同じ方法で取り込みます。

# %%
print("Game data generation...")
from pyspark.sql.functions import col, to_date
spark.conf.set("spark.sql.parquet.datetimeRebaseModeInWrite", "LEGACY")

schemaDDL = "game_id int, date_time string, date string, location string, home_team string, away_team string, error string, game_date string"
df_games = spark.read.csv(f"{data_path}/data/games.csv", sep=',', schema=schemaDDL)
df_games = df_games.withColumn("game_date", to_date(col("game_date"),'yyyy-MM-dd'))

spark.sql("drop table if exists games")
df_games.write.saveAsTable("games")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Game data generation...
# </div>

# %% [markdown]
# ### Points of Saleデータ
#
# POSデータも取り込みます。

# %%
print("Point of sales generation...")
data_rows = 1000000
df_spec = (dg.DataGenerator(spark, name="point_of_sale", rows=data_rows, partitions=4)
                            .withIdOutput()
                            .withColumn("game", IntegerType(), minValue=1, maxValue=97 , random=True)
                            .withColumn("item_purchased", IntegerType(), minValue=1, maxValue=364, random=True)
                            .withColumn("customer", IntegerType(), minValue=1, maxValue=1000, random=True))
                            
df_pos = df_spec.build().withColumnRenamed("id", "order_id")

# tableにデータを書き込みます。
spark.sql("drop table if exists point_of_sale")
df_pos.write.saveAsTable("point_of_sale")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Point of sales generation...
# </div>

# %% [markdown]
# ### 購入履歴(purchase_history)を取り込みます。

# %%
print("Purchase History to evaluate model efficiency after real game...")
import pandas as pd
pandasDF = pd.read_csv(f"{pandas_data_path}/data/purchase_history.csv")
df_spec = spark.createDataFrame(pandasDF, ['item_id', 'game_id', 'customer_id', 'recommended_item_purchased'])

spark.sql("drop table if exists purchase_history")
df_spec.write.saveAsTable("purchase_history")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Purchase History to evaluate model efficiency after real game...
# </div>

# %% [markdown]
# ## Step 2: Silver tableを作成する
#
# <img src="https://github.com/QuentinAmbard/databricks-demo/raw/main/media/resources/images/product_reco_stadium-2.png" width="1000px">

# %%
silver_sales_df = spark.sql('''
  SELECT * FROM ticket_sales t 
  JOIN point_of_sale p ON t.customer_id = p.customer
  JOIN stadium_vendors s ON p.item_purchased = s.item_id AND t.game_id = p.game;  
''')

spark.sql("drop table if exists silver_sales")
silver_sales_df.createTempView("silver_sales")
display(silver_sales_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>game_id</th><th>ticket_price</th><th>gate_entrance</th><th>section_number</th><th>row_number</th><th>seat_number</th><th>ticket_type</th><th>customer_name</th><th>phone_number</th><th>order_id</th><th>game</th><th>item_purchased</th><th>customer</th><th>vendor_id</th><th>vendor_location_number</th><th>vendor_name</th><th>vendor_scope</th><th>section</th><th>item_id</th><th>item_type</th><th>item</th><th>price</th><th>error</th></tr></thead><tbody><tr><td>409</td><td>3</td><td>301</td><td>a</td><td>131</td><td>3</td><td>24</td><td>packaged_game</td><td>Clinton Harris</td><td>+1-762-958-4295x0963</td><td>23</td><td>3</td><td>190</td><td>409</td><td>17</td><td>8</td><td>Streats of Detroit</td><td>Food</td><td>223</td><td>190</td><td>Pretzels</td><td>Pretzel</td><td>8</td><td>null</td></tr><tr><td>130</td><td>3</td><td>55</td><td>a</td><td>319</td><td>14</td><td>10</td><td>single_game</td><td>Jennifer Ferguson</td><td>360-055-4978x51577</td><td>41</td><td>3</td><td>124</td><td>130</td><td>17</td><td>2</td
show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------+
# item_id|item_purchases|
# +-------+--------------+
#     344|            44|
#     187|            43|
#      94|            43|
#     170|            43|
#     110|            43|
#      86|            42|
#      56|            41|
#     275|            41|
#     124|            41|
#     202|            40|
# +-------+--------------+
#
# </div>

# %% [markdown]
# ## Step 3: リコメンデーション・モデルの構築
#
# <img src="https://github.com/QuentinAmbard/databricks-demo/raw/main/media/resources/images/product_reco_stadium-3.png" width="1000px">
#
# <img src= https://databricks.com/wp-content/uploads/2020/04/databricks-adds-access-control-to-mlflow-model-registry_01.jpg width='500px' style='float: right'>
#
# ### MLFlowを用いたALSレコメンダーの構築
#
#
# Mlflowは、モデル自身を含むすべての実験メトリクスの追跡に使用されています。
# さらに、MLFlowを使って、レジストリにモデルをproductionとしてデプロイします。
# デプロイができたら、このモデルを再利用して、最終的なレコメンデーションを取得し、パーソナルなオファーをプッシュ通知で送ることができるようになります。

# %%
import mlflow
from pyspark.ml.recommendation import ALS

with mlflow.start_run() as run:
  #MLFlowで実行のパラメータなどを自動的にログに記録します。
  mlflow.pyspark.ml.autolog()
  
  df = spark.sql("select customer_id, item_id, count(item_id) as item_purchases from silver_sales group by customer_id, item_id")
  # ALSを使用してトレーニングデータからレコメンデーションモデルを構築する。
  # コールドスタート戦略を'drop'に設定して、NaN評価メトリクスにならないようにすることに注意してください。
  # 評価マトリックスは別の情報源から導出されます (つまり、他の情報から推測されます)。より良い結果を得るために、implicitPrefs を true に設定します。
  als = ALS(rank=3, userCol="customer_id", itemCol="item_id", ratingCol="item_purchases", implicitPrefs=True, seed=0, coldStartStrategy="nan")
  
  num_cores = sc.defaultParallelism
  als.setNumBlocks(num_cores)
  
  model = als.fit(df)
  
  # モデルもログに記録します。
  mlflow.spark.log_model(model, "spark-model")
    
  #　別のセルからこの実行の他の数値を追加する必要があるため、実行IDを取得しましょう。
  run_id = run.info.run_id
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DEBUG: Popen([&#39;git&#39;, &#39;version&#39;], cwd=/databricks/driver, universal_newlines=False, shell=None, istream=None)
# DEBUG: Popen([&#39;git&#39;, &#39;version&#39;], cwd=/databricks/driver, universal_newlines=False, shell=None, istream=None)
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;POST /api/2.0/mlflow/runs/create HTTP/1.1&#34; 200 None
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;POST /api/2.0/mlflow/runs/log-batch HTTP/1.1&#34; 200 None
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;POST /api/2.0/mlflow/runs/log-batch HTTP/1.1&#34; 200 None
# 2022/11/19 14:54:17 WARNING mlflow.pyspark.ml: Model ALS_0bf1d46afbb5 will not be autologged because it is not allowlisted or or because one or more of its nested models are not allowlisted. Call mlflow.spark.log_model() to explicitly log the model, or specify a custom allowlist via the spark.mlflow.pysparkml.autolog.logModelAllowlistFile Spark conf (see mlflow.pyspark.ml.autolog docs for more info).
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;GET /api/2.0/mlflow/runs/get?run_uuid=4f57d3dfd2f44b0491655d7da16b9e42&amp;run_id=4f57d3dfd2f44b0491655d7da16b9e42 HTTP/1.1&#34; 200 None
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;GET /api/2.0/mlflow/runs/get?run_uuid=4f57d3dfd2f44b0491655d7da16b9e42&amp;run_id=4f57d3dfd2f44b0491655d7da16b9e42 HTTP/1.1&#34; 200 None
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;GET /api/2.0/mlflow/runs/get?run_id=4f57d3dfd2f44b0491655d7da16b9e42 HTTP/1.1&#34; 200 None
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;POST /api/2.0/mlflow/artifacts/credentials-for-write HTTP/1.1&#34; 200 None
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;POST /api/2.0/mlflow/artifacts/credentials-for-write HTTP/1.1&#34; 200 None
# DEBUG: Starting new HTTPS connection (1): dbstorageeotkcdjymuxg2.blob.core.windows.net:443
# DEBUG: Starting new HTTPS connection (2): dbstorageeotkcdjymuxg2.blob.core.windows.net:443
# DEBUG: Starting new HTTPS connection (3): dbstorageeotkcdjymuxg2.blob.core.windows.net:443
# DEBUG: Starting new HTTPS connection (4): dbstorageeotkcdjymuxg2.blob.core.windows.net:443
# DEBUG: Starting new HTTPS connection (5): dbstorageeotkcdjymuxg2.blob.core.windows.net:443
# DEBUG: Starting new HTTPS connection (6): dbstorageeotkcdjymuxg2.blob.core.windows.net:443
# DEBUG: Starting new HTTPS connection (7): dbstorageeotkcdjymuxg2.blob.core.windows.net:443
# DEBUG: Starting new HTTPS connection (8): dbstorageeotkcdjymuxg2.blob.core.windows.net:443
# DEBUG: https://dbstorageeotkcdjymuxg2.blob.core.windows.net:443 &#34;PUT /jobs/3714643971017871/mlflow-tracking/3931049782386581/4f57d3dfd2f44b0491655d7da16b9e42/artifacts/spark-model/requirements.txt?sig=zXnUj0BxMTu7jVpTdOLumd4LJXcCc8HDkHIE6dE9P9g%3D&amp;se=2022-11-19T15%3A09%3A41Z&amp;sv=2019-02-02&amp;spr=https&amp;sp=w&amp;sr=b&amp;comp=block&amp;blockid=OGZiY2MyMTJmMTNmNGYyYmIyMDY4NGNjNjcyNTI1YTE%3D HTTP/1.1&#34; 201 0
# DEBUG: https://dbstorageeotkcdjymuxg2.blob.core.windows.net:443 &#34;PUT /jobs/3714643971017871/mlflow-tracking/3931049782386581/4f57d3dfd2f44b0491655d7da16b9e42/artifacts/spark-model/requirements.txt?sig=zXnUj0BxMTu7jVpTdOLumd4LJXcCc8HDkHIE6dE9P9g%3D&amp;se=2022-11-19T15%3A09%3A41Z&amp;sv=2019-02-02&amp;spr=https&amp;sp=w&amp;sr=b&amp;comp=blocklist HTTP/1.1&#34; 201 0
# DEBUG: https://dbstorageeotkcdjymuxg2.blob.core.windows.net:443 &#34;PUT /jobs/3714643971017871/mlflow-tracking/3931049782386581/4f57d3dfd2f44b0491655d7da16b9e42/artifacts/spark-model/sparkml/metadata/part-00000?sig=PuQro9xb3PiTKVyCFEGK1kRuB7p1FGKPVMPJzQKFzVU%3D&amp;se=2022-11-19T15%3A09%3A41Z&amp;sv=2019-02-02&amp;spr=https&amp;sp=w&amp;sr=b&amp;comp=block&amp;blockid=YmZlMmNmMTgyODcxNDljY2IyMDVjMGM3MzA4ZjFjMmE%3D HTTP/1.1&#34; 201 0
# DEBUG: https://dbstorageeotkcdjymuxg2.blob.core.windows.net:443 &#34;PUT /jobs/3714643971017871/mlflow-tracking/3931049782386581/4f57d3dfd2f44b0491655d7da16b9e42/artifacts/spark-model/sparkml/metadata/_SUCCESS?sig=Lz6N9jli8JRPa5soj8rhvAgBOBl8w9qBgYACD1jwkAA%3D&amp;se=2022-11-19T15%3A09%3A41Z&amp;sv=2019-02-02&amp;spr=https&amp;sp=w&amp;sr=b&amp;comp=blocklist HTTP/1.1&#34; 201 0
# DEBUG: https://dbstorageeotkcdjymuxg2.blob.core.windows.net:443 &#34;PUT /jobs/3714643971017871/mlflow-tracking/3931049782386581/4f57d3dfd2f44b0491655d7da16b9e42/artifacts/spark-model/conda.yaml?sig=s9wDB8mGk1FYfk1t2ojeL85GMIO6lJ1NKjCYopXqCP0%3D&amp;se=2022-11-19T15%3A09%3A41Z&amp;sv=2019-02-02&amp;spr=https&amp;sp=w&amp;sr=b&amp;comp=block&amp;blockid=YzA1ZDcwNTI4OTQwNDdkYzg3YmRhOGI3N2RmZmVhMzY%3D HTTP/1.1&#34; 201 0
# DEBUG: https://dbstorageeotkcdjymuxg2.blob.core.windows.net:443 &#34;PUT /jobs/3714643971017871/mlflow-tracking/3931049782386581/4f57d3dfd2f44b0491655d7da16b9e42/artifacts/spark-model/MLmodel?sig=n82uHpUIjyNfPeYv50poi1teq9XhktlMv7o3lMdBlKo%3D&amp;se=2022-11-19T15%3A09%3A41Z&amp;sv=2019-02-02&amp;spr=https&amp;sp=w&amp;sr=b&amp;comp=block&amp;blockid=MGFkNDYwZDhiYTg5NDU3ODg3MGNhNmE0ZjNjMjZkYTU%3D HTTP/1.1&#34; 201 0
# DEBUG: https://dbstorageeotkcdjymuxg2.blob.core.windows.net:443 &#34;PUT /jobs/3714643971017871/mlflow-tracking/3931049782386581/4f57d3dfd2f44b0491655d7da16b9e42/artifacts/spark-model/sparkml/stages/0_ALS_0bf1d46afbb5/userFactors/part-00000-tid-2779960393171190231-7919d187-4f03-4e21-87ae-475ddadd6a4e-2308-1-c000.snappy.parquet?sig=wVzoKTIS3HqAUjQubcohmjeguIwEOpB4f7DEmpWOsIE%3D&amp;se=2022-11-19T15%3A09%3A41Z&amp;sv=2019-02-02&amp;spr=https&amp;sp=w&amp;sr=b&amp;comp=block&amp;blockid=NDgzOTg2ODkzNjViNGNkODkwMjMyMWE3OTViMjhmYzM%3D HTTP/1.1&#34; 201 0
# DEBUG: https://dbstorageeotkcdjymuxg2.blob.core.windows.net:443 &#34;PUT /jobs/3714643971017871/mlflow-tracking/3931049782386581/4f57d3dfd2f44b0491655d7da16b9e42/artifacts/spark-model/sparkml/stages/0_ALS_0bf1d46afbb5/userFactors/part-00001-tid-2779960393171190231-7919d187-4f03-4e21-87ae-475ddadd6a4e-2309-1-c000.snappy.parquet?sig=3k5W7e2L%2FfoR5MueWDX0NZQCBEiRT02oRyVp%2FHns6Vk%3D&amp;se=2022-11-19T15%3A09%3A41Z&amp;sv=2019-02-02&amp;spr=https&amp;sp=w&amp;sr=b&amp;comp=block&amp;blockid=YzEwZDY1ZWY2ZWFhNDMzYmJkZDdkMjU5YTUxNjg5MDA%3D HTTP/1.1&#34; 201 0
# DEBUG: https://dbstorageeotkcdjymuxg2.blob.core.windows.net:443 &#34;PUT /jobs/3714643971017871/mlflow-tracking/3931049782386581/4f57d3dfd2f44b0491655d7da16b9e42/artifacts/spark-model/sparkml/stages/0_ALS_0bf1d46afbb5/userFactors/_committed_2779960393171190231?sig=DKE%2BcC1kjvjQS2%2B%2B9FZfmmOn%2BVr7ISsMEOlakdSQuQY%3D&amp;se=2022-11-19T15%3A09%3A41Z&amp;sv=2019-02-02&amp;spr=https&amp;sp=w&amp;sr=b&amp;comp=block&amp;blockid=NWQ5OTNhN2JjM2NkNDVhOGFlOGE4NGYyMThjOTc2MmU%3D HTTP/1.1&#34; 201 0
# DEBUG: https://dbstorageeotkcdjymuxg2.blob.core.windows.net:443 &#34;PUT /jobs/3714643971017871/mlflow-tracking/3931049782386581/4f57d3dfd2f44b0491655d7da16b9e42/artifacts/spark-model/sparkml/metadata/part-00000?sig=PuQro9xb3PiTKVyCFEGK1kRuB7p1FGKPVMPJzQKFzVU%3D&amp;se=2022-11-19T15%3A09%3A41Z&amp;sv=2019-02-02&amp;spr=https&amp;sp=w&amp;sr=b&amp;comp=blocklist HTTP/1.1&#34; 201 0
# DEBUG: https://dbstorageeotkcdjymuxg2.blob.core.windows.net:443 &#34;PUT /jobs/3714643971017871/mlflow-tracking/3931049782386581/4f57d3dfd2f44b0491655d7da16b9e42/artifacts/spark-model/sparkml/s

# %% [markdown]
# モデルをMLflowのモデルレジストリに登録します。

# %%
model_registered = mlflow.register_model("runs:/"+run_id+"/spark-model", "Stadium_Recommendation")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;POST /api/2.0/preview/mlflow/registered-models/create HTTP/1.1&#34; 400 None
# Registered model &#39;Stadium_Recommendation&#39; already exists. Creating a new version of this model...
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;GET /api/2.0/mlflow/runs/get?run_uuid=4f57d3dfd2f44b0491655d7da16b9e42&amp;run_id=4f57d3dfd2f44b0491655d7da16b9e42 HTTP/1.1&#34; 200 None
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;POST /api/2.0/preview/mlflow/model-versions/create HTTP/1.1&#34; 200 None
# 2022/11/19 14:54:43 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Stadium_Recommendation, version 7
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;GET /api/2.0/preview/mlflow/model-versions/get?name=Stadium_Recommendation&amp;version=7 HTTP/1.1&#34; 200 None
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;GET /api/2.0/preview/mlflow/model-versions/get?name=Stadium_Recommendation&amp;version=7 HTTP/1.1&#34; 200 None
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;GET /api/2.0/preview/mlflow/model-versions/get?name=Stadium_Recommendation&amp;version=7 HTTP/1.1&#34; 200 None
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;GET /api/2.0/preview/mlflow/model-versions/get?name=Stadium_Recommendation&amp;version=7 HTTP/1.1&#34; 200 None
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;GET /api/2.0/preview/mlflow/model-versions/get?name=Stadium_Recommendation&amp;version=7 HTTP/1.1&#34; 200 None
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;GET /api/2.0/preview/mlflow/model-versions/get?name=Stadium_Recommendation&amp;version=7 HTTP/1.1&#34; 200 None
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;GET /api/2.0/preview/mlflow/model-versions/get?name=Stadium_Recommendation&amp;version=7 HTTP/1.1&#34; 200 None
# </div>

# %% [markdown]
# 登録したモデルをProductionステージにプロモートします。

# %%
client = mlflow.tracking.MlflowClient()
print("registering model version "+model_registered.version+" as production model")
client.transition_model_version_stage(name = "Stadium_Recommendation", version = model_registered.version, stage = "Production", archive_existing_versions=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">registering model version 6 as production model
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;POST /api/2.0/preview/mlflow/model-versions/transition-stage HTTP/1.1&#34; 200 None
# Out[17]: &lt;ModelVersion: creation_timestamp=1668869409625, current_stage=&#39;Production&#39;, description=&#39;&#39;, last_updated_timestamp=1668869435925, name=&#39;Stadium_Recommendation&#39;, run_id=&#39;7b368eb36c1d4227a9b266067727bf4c&#39;, run_link=&#39;&#39;, source=&#39;dbfs:/databricks/mlflow-tracking/3931049782386581/7b368eb36c1d4227a9b266067727bf4c/artifacts/spark-model&#39;, status=&#39;READY&#39;, status_message=&#39;&#39;, tags={}, user_id=&#39;1791445848590786&#39;, version=&#39;6&#39;&gt;</div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## Step 4: モデルでレコメンデーションリストを作成する
#
# <img src="https://github.com/QuentinAmbard/databricks-demo/raw/main/media/resources/images/product_reco_stadium-4.png" width="1000px">
#
# これでMLFlowのレジストリにモデルが登録されたので、本番のパイプラインで使い始めることができます。
#
# あとはMLFlowからロードして推論を適用するだけです。

# %%
#                                                               　Stage/version
#                                        Model name                   |
#                                             |                       |
model = mlflow.spark.load_model(f'models:/Stadium_Recommendation/Production')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;POST /api/2.0/mlflow/registered-models/get-latest-versions HTTP/1.1&#34; 200 None
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;GET /api/2.0
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;GET /dbfs/databricks/mlflow-registry/5bbfbdcba5bb4faba7ef2aadaab0db7a/models/spark-model/sparkml/stages/0_ALS_9ecd763d688e/metadata/part-00000 HTTP/1.1&#34; 200 365
# DEBUG: https://southeastasia.azuredatabricks.net:443 &#34;GET /api/2.0/dbfs/list?path=%2Fdatabricks%2Fmlflow-registry%2F5bbfbdcba5bb4faba7ef2aadaab0db7a%2Fmodels%2Fspark-model%2Fsparkml%2Fstages%2F0_ALS_9ecd763d688e%2FuserFactors HTTP/1.1&#34; 200 None
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabricks.net:443
# DEBUG: Starting new HTTPS connection (1): southeastasia.azuredatabr
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# 顧客毎の上位10件のレコメンデーションアイテムを取得する
recommendations = model.stages[0].recommendForAllUsers(10)

spark.sql("drop table if exists silver_recommendations")
recommendations.createOrReplaceTempView("silver_recommendations")
display(recommendations)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/context.py:134: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>recommendations</th></tr></thead><tbody><tr><td>1</td><td>List(List(176, 0.14427546), List(277, 0.13161671), List(202, 0.1279852), List(89, 0.10887258), List(134, 0.10677869), List(144, 0.103235595), List(225, 0.09793375), List(13, 0.09731455), List(298, 0.09656529), List(112, 0.09282864))</td></tr><tr><td>2</td><td>List(List(86, 0.15349907), List(9, 0.1406347), List(242, 0.1399593), List(170, 0.13806199), List(137, 0.13628921), List(94, 0.12949055), List(229, 0.12005211), List(348, 0.11618918), List(83, 0.114641495), List(168, 0.11294341))</td></tr><tr><td>3</td><td>List(List(277, 0.15080534), List(202, 0.14858834), List(176, 0.1423753), List(89, 0.13583069), List(134, 0.12896664), List(112, 0.12317881), List(13, 0.12196676), List(124, 0.12008062), List(347, 0.119291686), List(298, 0.11450268))</td></tr><tr><td>4</td><td>List(List(9, 0.08039679), List(94, 0.07752084), List(16, 0.07671808), List(105, 0.0750363), List(358, 0.07308273), List(86, 0.07221078), List(175, 0.07065378), List(344, 0.06994742), List(171, 0.068965204), List(210, 0.066962376))</td></tr><tr><td>5</td><td>List(List(86, 0.16690658), List(242, 0.16258657), List(170, 0.16127582), List(137, 0.14963375), List(225, 0.14956415), List(25, 0.14404398), List(254, 0.13983487), List(93, 0.13295387), List(9, 0.13239591), List(229, 0.12969957))</td></tr><tr><td>6</td><td>List(List(86, 0.09751831), List(9, 0.0972947), List(94, 0.091394424), List(137, 0.08732138), List(170, 0.08711954), List(242, 0.0861789), List(348, 0.078760624), List(358, 0.07820542), List(33, 0.07675724), List(83, 0.07512931))</td></tr><tr><td>7</td><td>List(List(124, 0.24629103), List(202, 0.17663442), List(89, 0.17509808), List(277, 0.16421854), List(321, 0.16207178), List(199, 0.16136813), List(112, 0.16108565), List(179, 0.15421654), List(239, 0.14695744), List(305, 0.14580926))</td></tr><tr><td>8</td><td>List(List(124, 0.40366957), List(202, 0.33595598), List(89, 0.32072398), List(277, 0.31988606), List(112, 0.28936127), List(321, 0.28319845), List(347, 0.26163477), List(199, 0.25940818), List(13, 0.2579494), List(176, 0.25615487))</td></tr><tr><td>9</td><td>List(List(86, 0.23330273), List(9, 0.209794), List(242, 0.20734237), List(137, 0.20002082), List(229, 0.19354671), List(170, 0.19066472), List(348, 0.17991853), List(83, 0.17839867), List(94, 0.17730801), List(25, 0.15967326))</td></tr><tr><td>10</td><td>List(List(124, 0.15485469), List(179, 0.12603055), List(275, 0.12016465), List(244, 0.11577828), List(199, 0.115241766), List(354, 0.11479628), List(343, 0.11232121), List(31, 0.111399874), List(333, 0.11083978), List(45, 0.11025844))</td></tr><tr><td>11</td><td>List(List(86, 0.1253421), List(170, 0.123740345), List(242, 0.11944247), List(137, 0.11460837), List(9, 0.110615715), List(94, 0.10910332), List(225, 0.10515532), List(168, 0.103098065), List(25, 0.10172346), List(254, 0.099866785))</td></tr><tr><td>12</td><td>List(List(124, 0.124822184), List(179, 0.09349359), List(199, 0.08874806), List(354, 0.08528574), List(244, 0.08378303), List(275, 0.08242263), List(305, 0.08049644), List(343, 0.07914832), List(31, 0.078777276), List(190, 0.07843164))</td></tr><tr><td>13</td><td>List(List(86, 0.18656345), List(242, 0.18162669), List(170, 0.18058959), List(137, 0.16744883), List(225, 0.16701925), List(25, 0.16071981), List(254, 0.15613842), List(9, 0.14867514), List(93, 0.14847241), List(229, 0.1446371))</td></tr><tr><td>14</td><td>List(List(86, 0.10265881), List(242, 0.10014878), List(170, 0.09345798), List(25, 0.089643195), List(137, 0.08924954), List(225, 0.08893057), List(254, 0.085135385), List(229, 0.084444165), List(93, 0.08111646), List(319, 0.080886245))</td></tr><tr><td>15</td><td>List(List(124, 0.2374134), List(202, 0.19059695), List(89, 0.1897077), List(277, 0.18354417), List(179, 0.17987992), List(112, 0.17914423), List(199, 0.1719596), List(321,  ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## Step 5: レコメンデーション結果のフィルタリングと再ランク付け
#
#
# 顧客毎のレコメンドを展開し、アイテムや顧客の詳細を取得します。
#
# <img src="https://github.com/QuentinAmbard/databricks-demo/raw/main/media/resources/images/product_reco_stadium-5.png" width="1000px">

# %%
gold_recommendations_df = spark.sql('''
SELECT ci.*, vendor_id, vendor_location_number, vendor_name, vendor_scope, section, item_type, item, price, error
FROM stadium_vendors v
JOIN (SELECT customer_id, items.*
FROM   (SELECT customer_id, explode(recommendations) AS items
FROM   silver_recommendations) a) ci
ON v.item_id = ci.item_id
''') 

spark.sql("drop table if exists gold_recommendations")
gold_recommendations_df.createTempView("gold_recommendations")
spark.sql('select * from gold_recommendations').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>item_id</th><th>rating</th><th>vendor_id</th><th>vendor_location_number</th><th>vendor_name</th><th>vendor_scope</th><th>section</th><th>item_type</th><th>item</th><th>price</th><th>error</th></tr></thead><tbody><tr><td>1</td><td>176</td><td>0.14427546</td><td>17</td><td>7</td><td>Streats of Detroit</td><td>Food</td><td>217</td><td>Nachos</td><td>Nacho Grande</td><td>14</td><td>null</td></tr><tr><td>1</td><td>277</td><td>0.13161671</td><td>19</td><td>5</td><td>Tailgate Grill</td><td>Food</td><td>242</td><td>Non-Alcoholic</td><td>Regular or Large Soda</td><td>10</td><td>null</td></tr><tr><td>1</td><td>202</td><td>0.1279852</td><td>17</td><td>9</td><td>Streats of Detroit</td><td>Food</td><td>227</td><td>Snack</td><td>Peanuts</td><td>8</td><td>null</td></tr><tr><td>1</td><td>89</td><td>0.10887258</td><td>
>69</td></tr><tr><td>3</td><td>134</td><td>0.12896664</td><td>124</td><td>204</td><td>80</td></tr><tr><td>3</td><td>112</td><td>0.12317881</td><td>109</td><td>204</td><td>95</td></tr><tr><td>3</td><td>13</td><td>0.12196676</td><td>127</td><td>204</td><td>77</td></tr><tr><td>3</td><td>124</td><td>0.12008062</td><td>120</td><td>204</td><td>84</td></tr><tr><td>3</td><td>347</td><td>0.119291686</td><td>214</td><td>204</td><td>10</td></tr><tr><td>3</td><td>298</td><td>0.11450268</td><td>210</td><td>204</td><td>6</td></tr><tr><td>4</td><td>9</td><td>0.08039679</td><td>108</td><td>117</td><td>9</td></tr><tr><td>4</td><td>94</td><td>0.07752084</td><td>103</td><td>117</td><td>14</td></tr><tr><td>4</td><td>16</td><td>0.07671808</td><td>127</td><td>117</td><td>10</td></tr><tr><td>4</td><td>105</td><td>0.0750363</td><td>117</td><td>117</td><td>0</td></tr><tr><td>4</td><td>358</td><td>0.07308273</td><td>214</td><td>117</td><td>97</td></tr><tr><td>4</td><td>86</td><td>0.07221078</td><td>103</td><td>117</td><td>14</td></tr><tr><td>4</td><td>175</td><td>0.07065378</td><td>217</td><td>117</td><td>100</td></tr><tr><td>4</td><td>344</td><td>0.06994742</td><td>214</td><td>117</td><td>97</td></tr><tr><td>4</td><td>171</td><td>0.068965204</td><td>137</td><td>117</td><td>20</td></tr><tr><td>4</td><td>210</td><td>0.066962376</td><td>238</td><td>117</td><td>121</td></tr><tr><td>5</td><td>86</td><td>0.16690658</td><td>103</td><td>229</td><td>126</td></tr><tr><td>5</td><td>242</td><td>0.16258657</td><td>120</td><td>229</td><td>109</td></tr><tr><td>5</td><td>170</td><td>0.16127582</td><td>137</td><td>229</td><td>92</td></tr><tr><td>5</td><td>137</td><td>0.14963375</td><td>124</td><td>229</td><td>105</td></tr><tr><td>5</td><td>225</td><td>0. ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
final_recommendations_df = spark.sql("""
SELECT * FROM (
  SELECT *, RANK() OVER (PARTITION BY customer_id ORDER BY distance ASC) AS rnk FROM sections_recommendations
  ) WHERE rnk = 1
""")

spark.sql("drop table if exists final_recommendations")
final_recommendations_df.createTempView("final_recommendations")
spark.sql("SELECT * FROM final_recommendations").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-------+-----------+-------+--------------+--------+---+
# customer_id|item_id|     rating|section|section_number|distance|rnk|
# +-----------+-------+-----------+-------+--------------+--------+---+
#           1|     13| 0.09731455|    127|           127|       0|  1|
#           2|    348| 0.11618918|    214|           179|      35|  1|
#           3|    298| 0.11450268|    210|           204|       6|  1|
#           4|    105|  0.0750363|    117|           117|       0|  1|
#           5|    225| 0.14956415|    229|           229|       0|  1|
#           5|    229| 0.12969957|    229|           229|       0|  1|
#           6|    348|0.078760624|    214|           277|      63|  1|
#           6|    358| 0.07820542|    214|           277|      63|  1|
#           7|    239| 0.14695744|    244|           343|      99|  1|
#           8|    277| 0.31988606|    242|           280|      38|  1|
#           9|    348| 0.17991853|    214|           186|      28|  1|
#          10|    179| 0.12603055|    217|           221|       4|  1|
#          11|    170|0.123740345|    137|           165|      28|  1|
#          11|    168|0.103098065|    137|           165|      28|  1|
#          12|    124|0.124822184|    120|           116|       4|  1|
#          12|    244| 0.08378303|    120|           116|       4|  1|
#          13|    242| 0.18162669|    120|           121|       1|  1|
#          14|    319|0.080886245|    212|           180|      32|  1|
#          15|     89|  0.1897077|    135|           142|       7|  1|
#          16|    277| 0.08369845|    242|           252|      10|  1|
# +-----------+-------+-----------+-------+--------------+--------+---+
# only showing top 20 rows
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## Step 6: ファンにキャンペーンのオファーの送信
#
# これで、全顧客に送るべきアイテムが揃いました！通知をテストしてみましょう。
#
# <img src="https://github.com/QuentinAmbard/databricks-demo/raw/main/media/resources/images/product_reco_stadium-6.png" width="1000px">

# %%
# import IPython
# from IPython.display import display, HTML

def send_push_notification(title, subject, phone_number):
  #ノートブックを実行しているユーザーでメッセージを調整してください。リアルでは、顧客の詳細を含むテーブルから情報を取るべきです。
  first_name = "Yulan"
  import re
  subject = re.sub("\n", "<br/>", subject) 
  subject = re.sub("こんにちは！([0-9]*)", "こんにちは！"+first_name, subject) 
  subject = re.sub("大好きな([0-9]*)", "大好きなピザ", subject) 
  subject = re.sub("([0-9]*)で販売されている", "Goal Post Grill & Pizzeriaで販売されている", subject) 


  displayHTML(f"""<div style="border-radius: 10px; background-color: #adeaff; padding: 10px; width: 400px; box-shadow: 2px 2px 2px #F7f7f7; margin-bottom: 3px">
        <div style="padding-bottom: 5px"><img style="width:20px; margin-bottom: -3px" src="https://github.com/QuentinAmbard/databricks-demo/raw/main/media/resources/images/bell.png"/> <strong>{title}</strong></div>
        {subject}
        </div>""")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
recommendation = spark.sql("select * from final_recommendations where customer_id = 1").collect()[0]

title = "あなたにお得なキャンペーンオファー！"
subject= f"こんにちは！{recommendation['customer_id']}さん! 大好きな{recommendation['item_id']}を特別価格でご提供いたします。 {recommendation['section']}で販売されているので、チェックしてみてくださいね!" 

user_cell_phone = "<Put your real cell phone here to test the notification!>"
 
send_push_notification(title, subject, user_cell_phone)
# Out:
# <div style="border-radius: 10px; background-color: #adeaff; padding: 10px; width: 400px; box-shadow: 2px 2px 2px #F7f7f7; margin-bottom: 3px">
#         <div style="padding-bottom: 5px"><img style="width:20px; margin-bottom: -3px" src="https://github.com/QuentinAmbard/databricks-demo/raw/main/media/resources/images/bell.png"/> <strong>あなたにお得なキャンペーンオファー！</strong></div>
#         こんにちは！Yulanさん! 大好きなピザを特別価格でご提供いたします。 Goal Post Grill & Pizzeriaで販売されているので、チェックしてみてくださいね!
#         </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## Step 7: イベントキャンペーンとメトリクスのトラッキング
#
# イベント中は、すべての指標をリアルタイムで取得し、イベントのKPIをモニターするダッシュボードを構築することができます。
#
# ゲーム終了後、プロモーションの成功率を確認し、次のゲームに必要な調整を行うこともできます。
#
# <img src="https://github.com/QuentinAmbard/databricks-demo/raw/main/media/resources/images/product_reco_stadium-7.png" width="1000px">

# %%
## visualisation: Bar, Series groupings: item_purchased, Values: count, Aggregation: SUM

visual_df = spark.sql("""
select count(*) as count, item_purchased from (
  SELECT *, CASE WHEN recommended_item_purchased = 1 THEN 'Yes' ELSE 'No' END as item_purchased
  FROM final_recommendations r
  LEFT JOIN ticket_sales s USING(customer_id)
  LEFT JOIN purchase_history p USING(game_id, customer_id)) group by item_purchased
""")
visual_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------------+
# count|item_purchased|
# +-----+--------------+
#   511|            No|
#   818|           Yes|
# +-----+--------------+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
